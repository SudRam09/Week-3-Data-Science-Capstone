# %%
import requests
import lxml.html as lh
import bs4 as bs
import urllib.request
import numpy as np 
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
res = requests.get(url)
soup = bs.BeautifulSoup(res.content,'lxml')
table = soup.find_all('table')[0]
df = pd.read_html(str(table))
data = pd.read_json(df[0].to_json(orient='records'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c02d4790344e> in <module>
#       1 url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
#       2 res = requests.get(url)
# ----> 3 soup = bs.BeautifulSoup(res.content,'lxml')
#       4 table = soup.find_all('table')[0]
#       5 df = pd.read_html(str(table))
#
# NameError: name 'bs' is not defined

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-304fa4ce4ebd> in <module>
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
raw_data_selected = data[data['Borough'] != 'Not assigned']
raw_data_selected = raw_data_selected.groupby(['Borough', 'Postcode'], as_index=False).agg(','.join)
raw_data_selected.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-64b67ae3e5cb> in <module>
# ----> 1 raw_data_selected = data[data['Borough'] != 'Not assigned']
#       2 raw_data_selected = raw_data_selected.groupby(['Borough', 'Postcode'], as_index=False).agg(','.join)
#       3 raw_data_selected.head()
#
# NameError: name 'data' is not defined

# %%
geospatial_url = "https://cocl.us/Geospatial_data"
geospatial_data = pd.read_csv(geospatial_url)
geospatial_data.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
geospatial_data.columns = ['Postcode', 'Latitude', 'Longitude']

# %%
geospatial_data.columns
# Out:
# Index(['Postcode', 'Latitude', 'Longitude'], dtype='object')

# %%
merged_data = pd.merge(raw_data_selected, geospatial_data, on='Postcode')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-7fd62746f8e2> in <module>
# ----> 1 merged_data = pd.merge(raw_data_selected, geospatial_data, on='Postcode')
#
# NameError: name 'raw_data_selected' is not defined

# %%
merged_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-97a027fe26d2> in <module>
# ----> 1 merged_data.head()
#
# NameError: name 'merged_data' is not defined
